# %%
# !pip install gamspy
# Out:
# Requirement already satisfied: gamspy in /usr/local/lib/python3.10/dist-packages (0.12.3)
# Requirement already satisfied: gamsapi[control,transfer]>=46.1.0 in /usr/local/lib/python3.10/dist-packages (from gamspy) (46.4.1)
# Requirement already satisfied: gamspy-base>=46.3.1 in /usr/local/lib/python3.10/dist-packages (from gamspy) (46.4.1)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gamspy) (2.7.0)
# Requirement already satisfied: certifi>=2022.09.14 in /usr/local/lib/python3.10/dist-packages (from gamspy) (2024.2.2)
# Requirement already satisfied: urllib3>=2.0.7 in /usr/local/lib/python3.10/dist-packages (from gamspy) (2.0.7)
# Requirement already satisfied: pandas<2.2,>=1.5 in /usr/local/lib/python3.10/dist-packages (from gamsapi[control,transfer]>=46.1.0->gamspy) (2.0.3)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from gamsapi[control,transfer]>=46.1.0->gamspy) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gamsapi[control,transfer]>=46.1.0->gamspy) (1.11.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gamspy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gamspy) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gamspy) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2,>=1.5->gamsapi[control,transfer]>=46.1.0->gamspy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2,>=1.5->gamsapi[control,transfer]>=46.1.0->gamspy) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2,>=1.5->gamsapi[control,transfer]>=46.1.0->gamspy) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.2,>=1.5->gamsapi[control,transfer]>=46.1.0->gamspy) (1.16.0)

# %%
import math
import pandas as pd
import numpy as np
from gamspy import *
from scipy.stats import binom

# %%
values = list(range(11))
distribution = []
for k in values:
    distribution.append(binom.pmf(k, 10, 0.5))

# %%
distribution
# Out:
# [0.0009765624999999989,
#  0.009765625000000002,
#  0.04394531250000004,
#  0.1171875,
#  0.2050781249999999,
#  0.24609375000000003,
#  0.2050781249999999,
#  0.11718749999999999,
#  0.04394531250000004,
#  0.009765625000000002,
#  0.0009765625]

# %%
requiredDataFrame = []
lines = open("matrix.txt").readlines()
for line in lines:
    number = line.split()
    array = []
    for i in number:
        array.append(int(i))
    requiredDataFrame.append(array)

# %%
requiredDataFrame
# Out:
# [[2, 1, 2, 3, 2],
#  [3, 2, 1, 3, 2],
#  [1, 3, 2, 2, 1],
#  [3, 2, 3, 1, 1],
#  [2, 3, 1, 2, 3],
#  [1, 3, 3, 2, 2],
#  [3, 1, 2, 1, 3],
#  [2, 2, 3, 3, 1]]

# %%
requiredData = []
for i in range(8):
    for j in range(5):
        product = "product" + str(i+1)
        part = "part" + str(j+1)
        requiredData.append([product, part, requiredDataFrame[i][j]])

# %%
requiredData
# Out:
# [['product1', 'part1', 2],
#  ['product1', 'part2', 1],
#  ['product1', 'part3', 2],
#  ['product1', 'part4', 3],
#  ['product1', 'part5', 2],
#  ['product2', 'part1', 3],
#  ['product2', 'part2', 2],
#  ['product2', 'part3', 1],
#  ['product2', 'part4', 3],
#  ['product2', 'part5', 2],
#  ['product3', 'part1', 1],
#  ['product3', 'part2', 3],
#  ['product3', 'part3', 2],
#  ['product3', 'part4', 2],
#  ['product3', 'part5', 1],
#  ['product4', 'part1', 3],
#  ['product4', 'part2', 2],
#  ['product4', 'part3', 3],
#  ['product4', 'part4', 1],
#  ['product4', 'part5', 1],
#  ['product5', 'part1', 2],
#  ['product5', 'part2', 3],
#  ['product5', 'part3', 1],
#  ['product5', 'part4', 2],
#  ['product5', 'part5', 3],
#  ['product6', 'part1', 1],
#  ['product6', 'part2', 3],
#  ['product6', 'part3', 3],
#  ['product6', 'part4', 2],
#  ['product6', 'part5', 2],
#  ['product7', 'part1', 3],
#  ['product7', 'part2', 1],
#  ['product7', 'part3', 2],
#  ['product7', 'part4', 1],
#  ['product7', 'part5', 3],
#  ['product8', 'part1', 2],
#  ['product8', 'part2', 2],
#  ['product8', 'part3', 3],
#  ['product8', 'part4', 3],
#  ['product8', 'part5', 1]]

# %%
matrix = pd.DataFrame(
    requiredData,
    columns=["product", "part", "require"]
).set_index(["product", "part"])

# %%
matrix
# Out:
#                 require
# product  part
# product1 part1        2
#          part2        1
#          part3        2
#          part4        3
#          part5        2
# product2 part1        3
#          part2        2
#          part3        1
#          part4        3
#          part5        2
# product3 part1        1
#          part2        3
#          part3        2
#          part4        2
#          part5        1
# product4 part1        3
#          part2        2
#          part3        3
#          part4        1
#          part5        1
# product5 part1        2
#          part2        3
#          part3        1
#          part4        2
#          part5        3
# product6 part1        1
#          part2        3
#          part3        3
#          part4        2
#          part5        2
# product7 part1        3
#          part2        1
#          part3        2
#          part4        1
#          part5        3
# product8 part1        2
#          part2        2
#          part3        3
#          part4        3
#          part5        1

# %%
demand = []
demand.append(
    pd.DataFrame(
        [["product1", np.random.choice(np.arange(0,11), p=distribution)],
        ["product2", np.random.choice(np.arange(0,11), p=distribution)],
        ["product3", np.random.choice(np.arange(0,11), p=distribution)],
        ["product4", np.random.choice(np.arange(0,11), p=distribution)],
        ["product5", np.random.choice(np.arange(0,11), p=distribution)],
        ["product6", np.random.choice(np.arange(0,11), p=distribution)],
        ["product7", np.random.choice(np.arange(0,11), p=distribution)],
        ["product8", np.random.choice(np.arange(0,11), p=distribution)]],
        columns=["product", "demand1"]
    ).set_index("product")
)

demand.append(
    pd.DataFrame(
        [["product1", np.random.choice(np.arange(0,11), p=distribution)],
        ["product2", np.random.choice(np.arange(0,11), p=distribution)],
        ["product3", np.random.choice(np.arange(0,11), p=distribution)],
        ["product4", np.random.choice(np.arange(0,11), p=distribution)],
        ["product5", np.random.choice(np.arange(0,11), p=distribution)],
        ["product6", np.random.choice(np.arange(0,11), p=distribution)],
        ["product7", np.random.choice(np.arange(0,11), p=distribution)],
        ["product8", np.random.choice(np.arange(0,11), p=distribution)]],
        columns=["product", "demand2"]
    ).set_index("product")
)

# %%
demand
# Out:
# [          demand1
#  product
#  product1        3
#  product2        6
#  product3        5
#  product4        8
#  product5        7
#  product6        4
#  product7        5
#  product8        6,
#            demand2
#  product
#  product1        4
#  product2        5
#  product3        5
#  product4        5
#  product5        5
#  product6        6
#  product7        5
#  product8        5]

# %%
productCost = []
productSellingPrice = []
lines = open("product.txt").readlines()
for i in range (1, 9):
    line = lines[i].split()
    productCost.append(["product" + str(i), int(line[0])])
    productSellingPrice.append(["product" + str(i), int(line[1])])

productCost = pd.DataFrame(
    productCost,
    columns=["product", "cost (li)"]
).set_index("product")

productSellingPrice = pd.DataFrame(
    productSellingPrice,
    columns=["product", "selling price (qi)"]
).set_index("product")

# %%
productCost
# Out:
#           cost (li)
# product
# product1         81
# product2         94
# product3         77
# product4         90
# product5         92
# product6         91
# product7         84
# product8         93

# %%
productSellingPrice
# Out:
#           selling price (qi)
# product
# product1                 268
# product2                 311
# product3                 255
# product4                 297
# product5                 304
# product6                 301
# product7                 278
# product8                 307

# %%
partPrice = []
preorderPartCost = []
lines = open("part.txt").readlines()
for j in range (1,6):
    partPrice.append(["part"+str(j), int(lines[j].split()[0])])
    preorderPartCost.append(["part"+str(j), int(lines[j].split()[1])])

partSellingPrice = pd.DataFrame(
    partPrice,
    columns=["part", "selling price (sj)"]
).set_index("part")

preorderCost = pd.DataFrame(
    preorderPartCost,
    columns=["part", "preorder cost (bj)"]
).set_index("part")

S = len(demand)

# %%
partPrice
# Out:
# [['part1', 4], ['part2', 5], ['part3', 3], ['part4', 2], ['part5', 1]]

# %%
preorderPartCost
# Out:
# [['part1', 11], ['part2', 10], ['part3', 8], ['part4', 7], ['part5', 6]]

# %%
len(demand)
# Out:
# 2

# %%
m = Container()
i = Set(m, "i", description="product", records=productSellingPrice.index)
j = Set(m, "j", description="part", records=partSellingPrice.index)

A = Parameter(
    container=m,
    name="A",
    description="matrix",
    domain=[i,j],
    records=matrix.reset_index(),
)
d = [None]*S
for scenerio in range(S):
    d[scenerio] = Parameter(m, "d" + str(scenerio), domain=i, description="demand", records=demand[scenerio].reset_index())

l = Parameter(m, "l", domain=i, description="product cost", records=productCost.reset_index())
q = Parameter(m, "q", domain=i, description="product selling price", records=productSellingPrice.reset_index())
s = Parameter(m, "s", domain=j, description="part selling price", records=partSellingPrice.reset_index())
b = Parameter(m, "b", domain=j, description="preorder cost per part", records=preorderCost.reset_index())

x = Variable(m, "x", type="Positive", domain=j)
y = [None]*S
z = [None]*S

require = [None]*S
demandConstraint = [None]*S

obj = Sum(j, x[j]*b[j])

for scenerio in range(S):
    y[scenerio] = Variable(m, "y" + str(scenerio), type="Positive", domain=j)
    z[scenerio] = Variable(m, "z" + str(scenerio), type="Positive", domain=i)
    require[scenerio] = Equation(
        m, "require" + str(scenerio),
        domain=j, description="require number of parts j to product i"
    )
    require[scenerio][j] = y[scenerio][j] == x[j] - Sum(i, A[i,j]*z[scenerio][i])

    demandConstraint[scenerio] = Equation(
        m, "demand" + str(scenerio),
        domain=i, description="Demand for each product"
    )
    demandConstraint[scenerio][i] = z[scenerio][i] <= d[scenerio][i]

    obj += 0.5*Sum(i, (l[i]-q[i])*z[scenerio][i]) - 0.5*Sum(j, s[j]*y[scenerio][j])

# %%
l[i]

# %%
A.records
# Out:
#      product   part  value
# 0   product1  part1    2.0
# 1   product1  part2    1.0
# 2   product1  part3    2.0
# 3   product1  part4    3.0
# 4   product1  part5    2.0
# 5   product2  part1    3.0
# 6   product2  part2    2.0
# 7   product2  part3    1.0
# 8   product2  part4    3.0
# 9   product2  part5    2.0
# 10  product3  part1    1.0
# 11  product3  part2    3.0
# 12  product3  part3    2.0
# 13  product3  part4    2.0
# 14  product3  part5    1.0
# 15  product4  part1    3.0
# 16  product4  part2    2.0
# 17  product4  part3    3.0
# 18  product4  part4    1.0
# 19  product4  part5    1.0
# 20  product5  part1    2.0
# 21  product5  part2    3.0
# 22  product5  part3    1.0
# 23  product5  part4    2.0
# 24  product5  part5    3.0
# 25  product6  part1    1.0
# 26  product6  part2    3.0
# 27  product6  part3    3.0
# 28  product6  part4    2.0
# 29  product6  part5    2.0
# 30  product7  part1    3.0
# 31  product7  part2    1.0
# 32  product7  part3    2.0
# 33  product7  part4    1.0
# 34  product7  part5    3.0
# 35  product8  part1    2.0
# 36  product8  part2    2.0
# 37  product8  part3    3.0
# 38  product8  part4    3.0
# 39  product8  part5    1.0

# %%
l.records
# Out:
#     product  value
# 0  product1   81.0
# 1  product2   94.0
# 2  product3   77.0
# 3  product4   90.0
# 4  product5   92.0
# 5  product6   91.0
# 6  product7   84.0
# 7  product8   93.0

# %%
q.records
# Out:
#     product  value
# 0  product1  268.0
# 1  product2  311.0
# 2  product3  255.0
# 3  product4  297.0
# 4  product5  304.0
# 5  product6  301.0
# 6  product7  278.0
# 7  product8  307.0

# %%
s.records
# Out:
#     part  value
# 0  part1    4.0
# 1  part2    5.0
# 2  part3    3.0
# 3  part4    2.0
# 4  part5    1.0

# %%
b.records
# Out:
#     part  value
# 0  part1   11.0
# 1  part2   10.0
# 2  part3    8.0
# 3  part4    7.0
# 4  part5    6.0

# %%
modelTransport = Model(
    m, "modelTransport",
    problem="LP", equations=m.getEquations(),
    sense=Sense.MIN, objective=obj
)

modelTransport.solve(solver="CPLEX")
# Out:
#   Solver Status   Model Status Objective Num of Equations Num of Variables  \
# 0        Normal  OptimalGlobal   -4724.5               27               32
#
#   Model Type Solver Solver Time
# 0         LP  CPLEX       0.001

# %%
obj

# %%
print("x:\n", x.records)
# Out:
# x:
#         j  level  marginal  lower  upper  scale
# 0  part1   98.0       0.0    0.0    inf    1.0
# 1  part2   96.0       0.0    0.0    inf    1.0
# 2  part3   93.0       0.0    0.0    inf    1.0
# 3  part4   90.0       0.0    0.0    inf    1.0
# 4  part5   81.0       0.0    0.0    inf    1.0

# %%
print("y1:\n", y[0].records)
# Out:
# y1:
#         j  level  marginal  lower  upper  scale
# 0  part1    0.0       7.0    0.0    inf    1.0
# 1  part2    0.0       5.0    0.0    inf    1.0
# 2  part3    0.0       5.0    0.0    inf    1.0
# 3  part4    0.0       5.0    0.0    inf    1.0
# 4  part5    0.0       5.0    0.0    inf    1.0

# %%
print("z1:\n", z[0].records)
# Out:
# z1:
#            i  level  marginal  lower  upper  scale
# 0  product1    3.0       0.0    0.0    inf    1.0
# 1  product2    6.0       0.0    0.0    inf    1.0
# 2  product3    5.0       0.0    0.0    inf    1.0
# 3  product4    8.0       0.0    0.0    inf    1.0
# 4  product5    7.0       0.0    0.0    inf    1.0
# 5  product6    4.0       0.0    0.0    inf    1.0
# 6  product7    5.0       0.0    0.0    inf    1.0
# 7  product8    6.0       0.0    0.0    inf    1.0

# %%
print("y2:\n", y[1].records)
# Out:
# y2:
#         j  level  marginal  lower  upper  scale
# 0  part1   14.0       0.0    0.0    inf    1.0
# 1  part2    9.0       0.0    0.0    inf    1.0
# 2  part3    7.0       0.0    0.0    inf    1.0
# 3  part4    6.0       0.0    0.0    inf    1.0
# 4  part5    6.0       0.0    0.0    inf    1.0

# %%
print("z2:\n", z[1].records)
# Out:
# z2:
#            i  level  marginal  lower  upper  scale
# 0  product1    4.0       0.0    0.0    inf    1.0
# 1  product2    5.0       0.0    0.0    inf    1.0
# 2  product3    5.0       0.0    0.0    inf    1.0
# 3  product4    5.0       0.0    0.0    inf    1.0
# 4  product5    5.0       0.0    0.0    inf    1.0
# 5  product6    6.0       0.0    0.0    inf    1.0
# 6  product7    5.0       0.0    0.0    inf    1.0
# 7  product8    5.0       0.0    0.0    inf    1.0

# %%
print("objective result:", modelTransport.objective_value)
# Out:
# objective result: -4724.5
